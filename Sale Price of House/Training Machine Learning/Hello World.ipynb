# %%
import pandas as p
import numpy as np

# reads the csv file and stores the data into the variable (read_csv)
# if the file is in the same directory then just mentioning the name of the file does the job.

Raw_data = p.read_csv("/content/drive/MyDrive/Training Machine Learning/1. Regression - Module - (Housing Prices).csv")

# head(No. of rows) prints the first 5(by default) rows of the .csv file
# tail(No. of rows) prints the bottom rows of the .csv file (5 rows by default)
# to_string() is used to display all the values of the csv file

#print(Raw_data.head().to_string())

# dtype shows the datatypes of all the variables
Raw_data.dtypes

# describe() function is used to show the mean, standard deviation, max, min and descriptive values of the dataset.
# Out:
# ID                                             int64
# Date House was Sold                           object
# Sale Price                                   float64
# No of Bedrooms                                 int64
# No of Bathrooms                              float64
# Flat Area (in Sqft)                          float64
# Lot Area (in Sqft)                           float64
# No of Floors                                 float64
# Waterfront View                               object
# No of Times Visited                           object
# Condition of the House                        object
# Overall Grade                                  int64
# Area of the House from Basement (in Sqft)    float64
# Basement Area (in Sqft)                        int64
# Age of House (in Years)                        int64
# Renovated Year                                 int64
# Zipcode                                      float64
# Latitude                                     float64
# ...

# %%
Raw_data.describe(include='all')
# Out:
#                   ID  ... Lot Area after Renovation (in Sqft)
# count   2.161300e+04  ...                        21613.000000
# unique           NaN  ...                                 NaN
# top              NaN  ...                                 NaN
# freq             NaN  ...                                 NaN
# mean    4.580302e+09  ...                        12768.455652
# std     2.876566e+09  ...                        27304.179631
# min     1.000102e+06  ...                          651.000000
# 25%     2.123049e+09  ...                         5100.000000
# 50%     3.904930e+09  ...                         7620.000000
# 75%     7.308900e+09  ...                        10083.000000
# max     9.900000e+09  ...                       871200.000000
#
# [11 rows x 21 columns]

# %%
''' min() gives minimum
    max() gives maximum
    mean() gives average
    std() gives the standard deviation
    '''
Raw_data['Sale Price'].min()
# Out:
# 75000.0

# %%
'''Gives the percentile'''
Raw_data['Sale Price'].quantile(.25)
# Out:
# 321950.0

# %%
Raw_data['Condition of the House'].unique()
# Out:
# array(['Fair', 'Excellent', 'Good', 'Bad', 'Okay'], dtype=object)

# %%
Raw_data['Sale Price'].std()-np.std(Raw_data['Sale Price'])
# Out:
# 8.500931208662223

# %%
Raw_data['Sale Price'].std(ddof=0)-np.std(Raw_data['Sale Price'])
# Out:
# 0.0

# %%
#The same code from above written in different way
#ddof is the degree of freedom
Raw_data['Sale Price'].std()-np.std(Raw_data['Sale Price'],ddof=1)
# Out:
# 0.0

# %%
df2 = p.DataFrame({'X':['b','b','a','a'],'Y':[1,2,3,4]})
df2.groupby(['X']).agg([np.sum,np.mean,np.std])
# Out:
#     Y
#   sum mean       std
# X
# a   7  3.5  0.707107
# b   3  1.5  0.707107

# %%
a=[1,2,3]
b=[1,2]
a.extend(b)
a
# Out:
# [1, 2, 3, 1, 2]
